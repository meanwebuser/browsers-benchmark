# %%
import pandas as pd 
import ast 
import re 
import json 
# Read CSV
df = pd.read_csv('/home/z/my-project/upload/output_bench.csv')
  # Extract base engine name from the engine column d
def extract_base_engine(engine_name): 
    # Remove run number suffix like __run1, __run2, etc. 
    base = re.sub(r'__run\d+$', '', engine_name)
    df['base_engine'] = df['engine'].apply(extract_base_engine)
    return 
    # Get unique base engines print("Unique base engines:")
for e in sorted(df['base_engine'].unique()):
    print(f" - {e}")
    print(f"\nBase engine counts:") 
    print(df['base_engine'].value_counts())
